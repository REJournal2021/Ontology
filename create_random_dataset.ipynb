# %%
import json
import pandas as pd
from tqdm import tqdm_notebook
from IPython.display import HTML, display
import tabulate
import sqlite3
from sqlite3 import Error
import random
import copy
import math


human_labels = ('woman', 'men', 'boy', 'kid', 'child', 'guy', 'man', 'person', 'girl', 'lady', 'people')

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn

# %%
def setA_setB(A, B):
    """
    set A - set B
    """
    common_list = []
    diff_set = []
    comm_set = []
    for idx, row in A.iterrows():
        index_list = B[(B['Object_1'] == row['Object_1'])&(B['Relation'] == row['Relation'])&(B['Object_2'] == row['Object_2'])].index.tolist()
        if not index_list:
           diff_set.append(idx) 
        else:
           comm_set.append(idx)
    diff_cp = A.iloc[diff_set]
    com_cp = A.iloc[comm_set]
    return diff_cp, com_cp

def find_quantile(diff_set,q=0.95, max_im=20):
    quantile_95 = diff_set[diff_set.Count > diff_set.Count.quantile(q)]
    quantile_95 = quantile_95.sort_values('Count', ascending=False)
    quantile_95.reset_index(drop=True, inplace=True)
    quantile_95['count_down'] = max_im
#     im_to_add = []
    for index, row in quantile_95.iterrows():
        if len(quantile_95.at[index, 'images']) > quantile_95.at[index, 'count_down']:
            s_images = random.sample(quantile_95.at[index, 'images'], quantile_95.at[index, 'count_down'])
            quantile_95.at[index, 'images'] = s_images
        else:
            s_images = quantile_95.at[index, 'images']
        quantile_95.at[index, 'count_down'] = quantile_95.at[index, 'count_down'] - len(s_images)
#         im_to_add.extend(s_images)

#     im_to_add = list(set(im_to_add))
#     return im_to_add, quantile_95
    return quantile_95

def splite_data(data_df, train_size=50, val_size=10, test_size=10, dt=None):
    check_list = isinstance(data_df, list)
    if check_list:
        all_images = copy.deepcopy(data_df)
    elif not dt:
        all_images = [el.rsplit('/', 1)[1] for el in data_df['file_name'].to_list()]
    else:
        all_images = data_df['file_name'].to_list()
#     data_df = copy.deepcopy(data_df)
#     all_images = list(set([item for sublist in data_df['images'].tolist() for item in sublist]))
    
    train_images = random.sample(all_images, train_size)
    rem_images = list(set(all_images).difference(set(train_images)))
    val_images = random.sample(rem_images, val_size)
    rem_images = list(set(rem_images).difference(set(val_images)))
    test_images = random.sample(rem_images, test_size)
#     test_images = list(set(all_images).difference(set(train_images).union(set(val_images))))
    
#     print(set(train_images).intersection(set(val_images)))

#     assert len(all_images) == len(train_images) + len(val_images) + len(test_images)
    assert len(set(train_images).intersection(set(val_images))) == 0
    assert len(set(train_images).intersection(set(test_images))) == 0
    assert len(set(val_images).intersection(set(test_images))) == 0
    return train_images, val_images, test_images

def concat_df(df_list):
    bigdata = copy.deepcopy(df_list[0])
    for el in df_list[1:]:
        bigdata = bigdata.append(el, ignore_index=True)
    return bigdata

def find_index_of_images(img_df, image_name_list=None):
    index_id_list = []
    for el in image_name_list:
        index_ids = img_df.index[img_df['file_name'].str.contains(el)].tolist()
        image_id = [img_df.at[idx, 'id'] for idx in index_ids]
        if len(image_id) != 1:
            print(image_id)
        assert len(image_id) == 1
        index_id_list.append(index_ids[0])
    return index_id_list

def create_ann_df(ann_df, index_list):
    selected_ann_df = ann_df[ann_df['image_id'].isin([index_list[0] + 1])]
    for el in index_list[1:]:
        selected_ann_df = pd.concat([selected_ann_df,ann_df[ann_df['image_id'].isin([el + 1])]])
    return selected_ann_df

def create_img_df(img_df, index_list):
    selected_img_df = img_df.loc[[index_list[0]]]
    for el in index_list[1:]:
        selected_img_df = pd.concat([selected_img_df,img_df.loc[[el]]])
    return selected_img_df

def update_img_ids(aug_img_df, row=None, dataset='other'):
    last_id = aug_img_df.at[aug_img_df.index[-1], 'id']
    concat_df = pd.concat([aug_img_df, row])
    concat_df.reset_index(drop=True, inplace=True)
    concat_df.at[concat_df.index[-1], 'id'] = last_id + 1
#     if dataset == 'ch':
#         concat_df.at[concat_df.index[-1], 'file_name'] = 'CrowdHuman/Images/' + concat_df.at[concat_df.index[-1], 'file_name']
    return last_id + 1, concat_df

def uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df, dt='other'):
    selected_img_df = selected_img_df.sort_values('id')
    if dt == 'ch':
        selected_ann_df['height'] = ""
        selected_ann_df['width'] = ""
        for idx, row in selected_img_df.iterrows():
            new_image_id, aug_img_df = update_img_ids(aug_img_df, row=selected_img_df.loc[[idx]], dataset='ch')
            
            selected_ann_df.loc[selected_ann_df['image_id'] == idx + 1, 'height'] = aug_img_df.at[new_image_id -1, 'height']
            selected_ann_df.loc[selected_ann_df['image_id'] == idx + 1, 'width'] = aug_img_df.at[new_image_id -1, 'width']
            
            selected_ann_df.loc[selected_ann_df['image_id'] == idx + 1, 'image_id'] = new_image_id

    else:
        for idx, row in selected_img_df.iterrows():
            new_image_id, aug_img_df = update_img_ids(aug_img_df, row=selected_img_df.loc[[idx]])
            if 'image_id' in selected_ann_df.columns:
                selected_ann_df.loc[selected_ann_df['image_id'] == idx + 1, 'image_id'] = new_image_id
    
    return aug_img_df, selected_ann_df

def concat_ann_df(orig_df, add_df):
    ann_df_c = pd.concat([orig_df, add_df])
    ann_df_c.reset_index(drop=True, inplace=True)
    for idx, row in ann_df_c.iterrows():
        if idx + 1 != row['id']:
            ann_df_c.at[idx, 'id'] = idx + 1
    return ann_df_c

# %%
def add_area(df):
    df = copy.deepcopy(df)
    df['area'] = ""
    for idx, row in df.iterrows():
        bb = df.loc[df['id'] == idx + 1, 'bbox']
        bb = bb.tolist()[0]
        df.loc[df['id'] == idx + 1, 'area'] = bb[2]*bb[3]
    return df

# %% [markdown]
# # create annotatuion file
# #### selected data frames :

# %%
cp_file = 'datasets/cityperson_train.json'
f = open(cp_file)
cp_data = json.load(f)
# cp_licenses = cp_data['licenses']
cp_categories = cp_data['categories']
cp_images = cp_data['images']
cp_annotations = cp_data['annotations']
cp_img_df = pd.DataFrame(cp_images)
cp_ann_df = pd.DataFrame(cp_annotations)

# %%
print(cp_data['categories'])
# Out:
# [{'id': 1, 'name': 'pedestrain', 'supercategory': 'pedestrain'}]

# %%
# for idx, row in cp_img_df.iterrows():
#     cp_img_df.at[cp_img_df.index[idx], 'file_name'] = 'CityPersons/' + cp_img_df.at[cp_img_df.index[idx], 'file_name']
aug_img_df = copy.deepcopy(cp_img_df)
aug_img_df
# Out:
#         id  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 2524  2525
# 2525  2526
# 2526  2527
# 2527  2528
# 2528  2529
#
#                                                                                                     file_name  \
# 0         CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000117_000019_leftImg8bit.png
# 1         CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000080_000019_leftImg8bit.png
# 2         CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000113_000019_leftImg8bit.png
# 3         CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000103_000019_leftImg8bit.png
# 4         CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000063_000019_leftImg8bit.png
# ...                                                                                                       ...
# 2524  CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/tubingen/tubingen_000130_000019_leftImg8bit.png
# 2525  CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/tubingen/tubingen_000126_000019_leftImg8bit.png
# 2526  CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/tubingen/tubingen_000045_000019_leftImg8bit.png
# 2527  CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/tubingen/tubingen_000016_000019_leftImg8bit.png
# 2528  CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/tubingen/tubingen_000122_000019_leftImg8bit.png
#
#       width  height               date_captured  license coco_url flickr_url
# 0      2048    1024  2019-07-25 11:20:43.195846        1
# 1      2048    1024  2019-07-25 11:20:43.195846        1
# 2      2048    1024  2019-07-25 11:20:43.195846        1
# 3      2048    1024  2019-07-25 11:20:43.195846        1
# 4      2048    1024  2019-07-25 11:20:43.195846        1
# ...     ...     ...                         ...      ...      ...        ...
# 2524   2048    1024  2019-07-25 11:20:43.195846        1
# 2525   2048    1024  2019-07-25 11:20:43.195846        1
# 2526   2048    1024  2019-07-25 11:20:43.195846        1
# 2527   2048    1024  2019-07-25 11:20:43.195846        1
# 2528   2048    1024  2019-07-25 11:20:43.195846        1
#
# [2529 rows x 8 columns]

# %%
# cp_ann_df = add_area(cp_ann_df)
cp_ann_df
# Out:
#           id  image_id  category_id  iscrowd                         bbox  \
# 0          1         1            1     True    [1137.0, 307.0, 8.0, 9.0]
# 1          2         1            1     True  [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1     True  [1034.0, 366.0, 31.0, 75.0]
# 3          4         2            1    False  [281.0, 381.0, 89.0, 216.0]
# 4          5         2            1    False  [602.0, 413.0, 60.0, 146.0]
# ...      ...       ...          ...      ...                          ...
# 23651  23652      2529            1    False  [1662.0, 366.0, 26.0, 63.0]
# 23652  23653      2529            1    False  [1642.0, 370.0, 25.0, 61.0]
# 23653  23654      2529            1    False  [1633.0, 369.0, 21.0, 51.0]
# 23654  23655      2529            1     True    [446.0, 351.0, 8.0, 65.0]
# 23655  23656      2529            1     True  [1570.0, 376.0, 20.0, 48.0]
#
#        width  height     area
# 0       2048    1024     72.0
# 1       2048    1024    540.0
# 2       2048    1024   2325.0
# 3       2048    1024  19224.0
# 4       2048    1024   8760.0
# ...      ...     ...      ...
# 23651   2048    1024   1638.0
# 23652   2048    1024   1525.0
# 23653   2048    1024   1071.0
# 23654   2048    1024    520.0
# 23655   2048    1024    960.0
#
# [23656 rows x 8 columns]

# %%
cp_info = copy.deepcopy(cp_data['info'])
cp_cat = copy.deepcopy(cp_data['categories'])
cp_data['categories']
# Out:
# [{'id': 1, 'name': 'pedestrain', 'supercategory': 'pedestrain'}]

# %% [markdown]
# ## ECP

# %%
ecp_file = 'json_files/EuroCity/day_train_all.json'
f = open(ecp_file)
ecp_data = json.load(f)
ecp_licenses = ecp_data['licenses']
ecp_categories = ecp_data['categories']
ecp_images = ecp_data['images']
ecp_annotations = ecp_data['annotations']
ecp_img_df = pd.DataFrame(ecp_images)
ecp_ann_df = pd.DataFrame(ecp_annotations)
ecp_img_df.shape[0]
# Out:
# 23892

# %%
print(ecp_data['categories'])
# Out:
# [{'id': 1, 'name': 'pedestrain', 'supercategory': 'pedestrain'}]

# %%
for idx, row in ecp_img_df.iterrows():
    ecp_img_df.at[ecp_img_df.index[idx], 'file_name'] = 'EuroCity/' + ecp_img_df.at[ecp_img_df.index[idx], 'file_name']
ecp_img_df
# Out:
#           id                                                 file_name  width  \
# 0          1  EuroCity/ECP/day/img/train/wuerzburg/wuerzburg_00516.png   1920
# 1          2  EuroCity/ECP/day/img/train/wuerzburg/wuerzburg_00142.png   1920
# 2          3  EuroCity/ECP/day/img/train/wuerzburg/wuerzburg_00294.png   1920
# 3          4  EuroCity/ECP/day/img/train/wuerzburg/wuerzburg_00106.png   1920
# 4          5  EuroCity/ECP/day/img/train/wuerzburg/wuerzburg_00470.png   1920
# ...      ...                                                       ...    ...
# 23887  23888      EuroCity/ECP/day/img/train/potsdam/potsdam_00494.png   1920
# 23888  23889      EuroCity/ECP/day/img/train/potsdam/potsdam_00029.png   1920
# 23889  23890      EuroCity/ECP/day/img/train/potsdam/potsdam_00514.png   1920
# 23890  23891      EuroCity/ECP/day/img/train/potsdam/potsdam_00360.png   1920
# 23891  23892      EuroCity/ECP/day/img/train/potsdam/potsdam_00022.png   1920
#
#        height               date_captured  license coco_url flickr_url
# 0        1024  2019-11-03 07:44:18.143034        1
# 1        1024  2019-11-03 07:44:18.143034        1
# 2        1024  2019-11-03 07:44:18.143034        1
# 3        1024  2019-11-03 07:44:18.143034        1
# 4        1024  2019-11-03 07:44:18.143034        1
# ...       ...                         ...      ...      ...        ...
# 23887    1024  2019-11-03 07:44:18.143034        1
# 23888    1024  2019-11-03 07:44:18.143034        1
# 23889    1024  2019-11-03 07:44:18.143034        1
# 23890    1024  2019-11-03 07:44:18.143034        1
# 23891    1024  2019-11-03 07:44:18.143034        1
#
# [23892 rows x 8 columns]

# %%
train_img_ecp, val_img_ecp, test_ecp_img = splite_data(ecp_img_df, train_size=871, val_size=168, test_size=155)
# train_img_ecp

# %%
index_id_list = find_index_of_images(ecp_img_df, image_name_list=train_img_ecp)

selected_ecp_img_df = create_img_df(ecp_img_df, index_id_list)
selected_ecp_ann_df = create_ann_df(ecp_ann_df, index_id_list)
print(selected_ecp_ann_df.shape[0])
print(selected_ecp_img_df.shape[0])
# Out:
# 7528
# 871

# %%
train_img_ecp
# Out:
# ['torino_00423.png',
#  'zagreb_00056.png',
#  'montpellier_00471.png',
#  'hamburg_00256.png',
#  'dresden_00206.png',
#  'ulm_00429.png',
#  'hamburg_00139.png',
#  'basel_00328.png',
#  'budapest_00137.png',
#  'bologna_00726.png',
#  'brno_00625.png',
#  'dresden_00415.png',
#  'bologna_00289.png',
#  'bologna_00121.png',
#  'ljubljana_00406.png',
#  'barcelona_00710.png',
#  'leipzig_00059.png',
#  'budapest_00461.png',
#  'pisa_00507.png',
#  'prague_00193.png',
#  'amsterdam_00966.png',
#  'bologna_00984.png',
#  'stuttgart_00531.png',
#  'brno_00682.png',
#  'dresden_00721.png',
#  'budapest_00596.png',
#  'prague_00090.png',
#  'szczecin_00226.png',
#  'bologna_00854.png',
#  'barcelona_00092.png',
#  'marseille_00429.png',
#  'brno_00669.png',
#  'potsdam_00266.png',
#  'roma_00115.png',
#  'basel_00276.png',
#  'stuttgart_00016.png',
#  'prague_00904.png',
#  'prague_00082.png',
#  'bratislava_00646.png',
#  'roma_00836.png',
#  'leipzig_00305.png',
#  'prague_00879.png',
#  'wuerzburg_00194.png',
#  'marseille_00386.png',
#  'prague_01313.png',
#  'firenze_00034.png',
#  'zagreb_00414.png',
#  'montpellier_00228.png',
#  'ljubljana_00067.png',
#  'torino_00559.png',
#  'szczecin_00295.png',
#  'torino_00455.png',
#  'torino_00785.png',
#  'leipzig_00405.png',
#  'amsterdam_00815.png',
#  'milano_00122.png',
#  'torino_00226.png',
#  'brno_00753.png',
#  'zagreb_00445.png',
#  'basel_00268.png',
#  'hamburg_00482.png',
#  'bratislava_00675.png',
#  'prague_00429.png',
#  'zagreb_00425.png',
#  'dresden_00577.png',
#  'milano_00408.png',
#  'brno_00784.png',
#  'milano_00690.png',
#  'ljubljana_00762.png',
#  'koeln_00123.png',
#  'torino_00990.png',
#  'prague_01039.png',
#  'pisa_00611.png',
#  'barcelona_00274.png',
#  'milano_00545.png',
#  'dresden_00709.png',
#  'ljubljana_00837.png',
#  'amsterdam_00453.png',
#  'firenze_01030.png',
#  'toulouse_00301.png',
#  'stuttgart_00360.png',
#  'zagreb_00570.png',
#  'marseille_00146.png',
#  'zuerich_00209.png',
#  'ljubljana_00556.png',
#  'torino_00195.png',
#  'hamburg_00412.png',
#  'barcelona_00249.png',
#  'amsterdam_00449.png',
#  'zagreb_00461.png',
#  'roma_00128.png',
#  'ljubljana_00051.png',
#  'szczecin_00325.png',
#  'koeln_00161.png',
#  'nuernberg_00778.png',
#  'nuernberg_00066.png',
#  'leipzig_00226.png',
#  'basel_00310.png',
#  'prague_00880.png',
#  'prague_00652.png',
#  'brno_00419.png',
#  'ljubljana_00413.png',
#  'prague_00037.png',
#  'ljubljana_00198.png',
#  'bologna_01152.png',
#  'bologna_00791.png',
#  'hamburg_00094.png',
#  'stuttgart_00044.png',
#  'bratislava_00222.png',
#  'szczecin_00193.png',
#  'montpellier_00480.png',
#  'torino_00629.png',
#  'brno_00426.png',
#  'roma_00714.png',
#  'basel_00605.png',
#  'firenze_00791.png',
#  'potsdam_00098.png',
#  'roma_00614.png',
#  'toulouse_00134.png',
#  'wuerzburg_00148.png',
#  'stuttgart_00402.png',
#  'amsterdam_00432.png',
#  'brno_00318.png',
#  'budapest_00136.png',
#  'milano_00740.png',
#  'prague_00531.png',
#  'hamburg_00439.png',
#  'amsterdam_00506.png',
#  'ljubljana_00239.png',
#  'roma_00650.png',
#  'montpellier_00188.png',
#  'amsterdam_00186.png',
#  'budapest_00706.png',
#  'pisa_00439.png',
#  'wuerzburg_00125.png',
#  'marseille_01132.png',
#  'potsdam_00175.png',
#  'toulouse_00179.png',
#  'barcelona_01159.png',
#  'barcelona_00125.png',
#  'milano_00248.png',
#  'firenze_00560.png',
#  'brno_00295.png',
#  'torino_00352.png',
#  'wuerzburg_00101.png',
#  'amsterdam_00009.png',
#  'wuerzburg_00403.png',
#  'barcelona_00612.png',
#  'marseille_00533.png',
#  'torino_00788.png',
#  'amsterdam_00789.png',
#  'amsterdam_00803.png',
#  'potsdam_00011.png',
#  'nuernberg_00754.png',
#  'prague_00914.png',
#  'barcelona_01007.png',
#  'bologna_00821.png',
#  'bratislava_00426.png',
#  'firenze_00654.png',
#  'bratislava_00615.png',
#  'szczecin_00187.png',
#  'nuernberg_00734.png',
#  'amsterdam_00138.png',
#  'bologna_00113.png',
#  'toulouse_00370.png',
#  'ulm_00593.png',
#  'pisa_00376.png',
#  'budapest_00697.png',
#  'koeln_00026.png',
#  'milano_00432.png',
#  'prague_01145.png',
#  'bologna_00695.png',
#  'pisa_00225.png',
#  'milano_00199.png',
#  'brno_00057.png',
#  'torino_00317.png',
#  'zuerich_00013.png',
#  'ljubljana_00751.png',
#  'berlin_00349.png',
#  'prague_01324.png',
#  'firenze_00752.png',
#  'brno_00441.png',
#  'potsdam_00156.png',
#  'brno_00620.png',
#  'roma_00976.png',
#  'brno_00014.png',
#  'bologna_00519.png',
#  'ljubljana_00035.png',
#  'brno_00834.png',
#  'bratislava_00567.png',
#  'barcelona_01053.png',
#  'lyon_00151.png',
#  'bologna_00091.png',
#  'amsterdam_00732.png',
#  'dresden_00424.png',
#  'prague_01140.png',
#  'basel_00079.png',
#  'toulouse_00553.png',
#  'stuttgart_00335.png',
#  'roma_00819.png',
#  'torino_00359.png',
#  'berlin_00131.png',
#  'ljubljana_00314.png',
#  'zuerich_00132.png',
#  'nuernberg_00017.png',
#  'roma_00108.png',
#  'roma_00538.png',
#  'bologna_00356.png',
#  'prague_00218.png',
#  'ljubljana_00689.png',
#  'amsterdam_01030.png',
#  'roma_00016.png',
#  'roma_00122.png',
#  'zagreb_00175.png',
#  'marseille_01251.png',
#  'potsdam_00130.png',
#  'bologna_00383.png',
#  'lyon_00035.png',
#  'torino_00294.png',
#  'milano_00500.png',
#  'milano_00070.png',
#  'prague_00416.png',
#  'ulm_00577.png',
#  'ulm_00215.png',
#  'bologna_00408.png',
#  'bologna_00772.png',
#  'bologna_00560.png',
#  'amsterdam_00760.png',
#  'lyon_00128.png',
#  'brno_00462.png',
#  'potsdam_00055.png',
#  'szczecin_00085.png',
#  'budapest_00805.png',
#  'bologna_00106.png',
#  'prague_00294.png',
#  'wuerzburg_00187.png',
#  'marseille_00637.png',
#  'barcelona_00445.png',
#  'stuttgart_00138.png',
#  'bratislava_00532.png',
#  'bologna_00756.png',
#  'ljubljana_00325.png',
#  'basel_00231.png',
#  'szczecin_00266.png',
#  'zuerich_00173.png',
#  'leipzig_00022.png',
#  'prague_01175.png',
#  'zagreb_00045.png',
#  'milano_00778.png',
#  'barcelona_00562.png',
#  'ulm_00126.png',
#  'prague_01130.png',
#  'brno_00201.png',
#  'milano_00446.png',
#  'ljubljana_00326.png',
#  'bologna_00817.png',
#  'szczecin_00232.png',
#  'montpellier_00081.png',
#  'pisa_00526.png',
#  'ljubljana_00003.png',
#  'bratislava_00689.png',
#  'budapest_00305.png',
#  'firenze_00425.png',
#  'firenze_00284.png',
#  'marseille_00833.png',
#  'firenze_00338.png',
#  'marseille_01186.png',
#  'prague_00168.png',
#  'pisa_00007.png',
#  'firenze_00922.png',
#  'pisa_00183.png',
#  'berlin_00244.png',
#  'stuttgart_00048.png',
#  'dresden_00728.png',
#  'torino_00174.png',
#  'leipzig_00063.png',
#  'firenze_00683.png',
#  'stuttgart_00277.png',
#  'hamburg_00553.png',
#  'koeln_00131.png',
#  'wuerzburg_00017.png',
#  'roma_00148.png',
#  'marseille_00982.png',
#  'marseille_00426.png',
#  'bologna_00242.png',
#  'prague_00127.png',
#  'roma_00877.png',
#  'bratislava_00363.png',
#  'marseille_00108.png',
#  'dresden_00528.png',
#  'lyon_00059.png',
#  'stuttgart_00544.png',
#  'nuernberg_00761.png',
#  'marseille_00081.png',
#  'firenze_00213.png',
#  'amsterdam_00969.png',
#  'nuernberg_00469.png',
#  'szczecin_00055.png',
#  'ljubljana_00877.png',
#  'zuerich_00084.png',
#  'toulouse_00199.png',
#  'ljubljana_00812.png',
#  'roma_00627.png',
#  'zuerich_00143.png',
#  'brno_00141.png',
#  'firenze_00470.png',
#  'stuttgart_00304.png',
#  'dresden_00534.png',
#  'potsdam_00444.png',
#  'berlin_00246.png',
#  'torino_00844.png',
#  'roma_00779.png',
#  'zagreb_00428.png',
#  'leipzig_00286.png',
#  'bratislava_00487.png',
#  'hamburg_00288.png',
#  'montpellier_00532.png',
#  'szczecin_00092.png',
#  'prague_00061.png',
#  'amsterdam_00476.png',
#  'marseille_01196.png',
#  'firenze_00761.png',
#  'nuernberg_00143.png',
#  'barcelona_00259.png',
#  'nuernberg_00835.png',
#  'ljubljana_00574.png',
#  'barcelona_00645.png',
#  'bratislava_00185.png',
#  'zagreb_00014.png',
#  'brno_00331.png',
#  'basel_00150.png',
#  'budapest_00624.png',
#  'marseille_00006.png',
#  'ulm_00286.png',
#  'firenze_00928.png',
#  'hamburg_00385.png',
#  'koeln_00147.png',
#  'nuernberg_00888.png',
#  'hamburg_00061.png',
#  'prague_01263.png',
#  'ljubljana_00585.png',
#  'budapest_00387.png',
#  'marseille_00658.png',
#  'stuttgart_00032.png',
#  'budapest_00339.png',
#  'bratislava_00173.png',
#  'leipzig_00000.png',
#  'bologna_00584.png',
#  'toulouse_00245.png',
#  'pisa_00489.png',
#  'bologna_00199.png',
#  'marseille_00216.png',
#  'budapest_00414.png',
#  'prague_00765.png',
#  'firenze_00206.png',
#  'bologna_00114.png',
#  'montpellier_00041.png',
#  'potsdam_00360.png',
#  'zagreb_00364.png',
#  'montpellier_00531.png',
#  'wuerzburg_00079.png',
#  'roma_00055.png',
#  'zagreb_00198.png',
#  'zagreb_00538.png',
#  'dresden_00083.png',
#  'potsdam_00408.png',
#  'torino_00962.png',
#  'pisa_00407.png',
#  'hamburg_00304.png',
#  'roma_00979.png',
#  'marseille_00457.png',
#  'montpellier_00619.png',
#  'firenze_00468.png',
#  'brno_00041.png',
#  'bologna_00617.png',
#  'milano_00242.png',
#  'amsterdam_00697.png',
#  'prague_00688.png',
#  'bologna_00492.png',
#  'stuttgart_00208.png',
#  'bratislava_00153.png',
#  'nuernberg_00822.png',
#  'barcelona_00484.png',
#  'barcelona_01094.png',
#  'brno_00722.png',
#  'roma_00266.png',
#  'nuernberg_00100.png',
#  'ulm_00493.png',
#  'budapest_00296.png',
#  'toulouse_00181.png',
#  'roma_00983.png',
#  'potsdam_00179.png',
#  'torino_00397.png',
#  'berlin_00044.png',
#  'amsterdam_00948.png',
#  'brno_00030.png',
#  'prague_00028.png',
#  'amsterdam_00540.png',
#  'toulouse_00488.png',
#  'torino_00833.png',
#  'firenze_01065.png',
#  'bratislava_00424.png',
#  'pisa_00224.png',
#  'ljubljana_00416.png',
#  'szczecin_00248.png',
#  'amsterdam_00350.png',
#  'wuerzburg_00648.png',
#  'potsdam_00131.png',
#  'toulouse_00040.png',
#  'leipzig_00078.png',
#  'firenze_00004.png',
#  'berlin_00207.png',
#  'ljubljana_00098.png',
#  'stuttgart_00288.png',
#  'zagreb_00491.png',
#  'zagreb_00711.png',
#  'nuernberg_00130.png',
#  'stuttgart_00092.png',
#  'dresden_00712.png',
#  'dresden_00376.png',
#  'toulouse_00103.png',
#  'hamburg_00065.png',
#  'wuerzburg_00366.png',
#  'bratislava_00421.png',
#  'marseille_00554.png',
#  'nuernberg_00074.png',
#  'potsdam_00152.png',
#  'zagreb_00653.png',
#  'amsterdam_00979.png',
#  'marseille_00621.png',
#  'prague_00811.png',
#  'zuerich_00105.png',
#  'amsterdam_00682.png',
#  'firenze_00242.png',
#  'berlin_00333.png',
#  'pisa_00136.png',
#  'bologna_00974.png',
#  'ljubljana_00339.png',
#  'milano_00040.png',
#  'ljubljana_00208.png',
#  'bratislava_00662.png',
#  'stuttgart_00350.png',
#  'pisa_00378.png',
#  'bologna_00119.png',
#  'basel_00439.png',
#  'toulouse_00174.png',
#  'bratislava_00389.png',
#  'firenze_00307.png',
#  'nuernberg_00539.png',
#  'budapest_00398.png',
#  'leipzig_00138.png',
#  'wuerzburg_00519.png',
#  'montpellier_00023.png',
#  'amsterdam_00573.png',
#  'dresden_00685.png',
#  'prague_00116.png',
#  'brno_00420.png',
#  'bologna_00354.png',
#  'barcelona_00997.png',
#  'marseille_00797.png',
#  'prague_00802.png',
#  'barcelona_00747.png',
#  'leipzig_00079.png',
#  'roma_01124.png',
#  'budapest_00808.png',
#  'firenze_00086.png',
#  'ljubljana_00034.png',
#  'ljubljana_00213.png',
#  'budapest_00081.png',
#  'barcelona_00996.png',
#  'bologna_00928.png',
#  'nuernberg_00796.png',
#  'toulouse_00276.png',
#  'barcelona_00413.png',
#  'ljubljana_00637.png',
#  'amsterdam_01059.png',
#  'montpellier_00434.png',
#  'prague_01147.png',
#  'leipzig_00177.png',
#  'pisa_00621.png',
#  'bologna_00047.png',
#  'amsterdam_00090.png',
#  'firenze_01041.png',
#  'roma_00331.png',
#  'zagreb_00436.png',
#  'montpellier_00078.png',
#  'dresden_00734.png',
#  'firenze_00645.png',
#  'leipzig_00018.png',
#  'pisa_00486.png',
#  'pisa_00242.png',
#  'firenze_00136.png',
#  'wuerzburg_00234.png',
#  'barcelona_00602.png',
#  'roma_00660.png',
#  'hamburg_00492.png',
#  'budapest_00611.png',
#  'firenze_00910.png',
#  'hamburg_00362.png',
#  'barcelona_00810.png',
#  'ljubljana_00450.png',
#  'montpellier_00070.png',
#  'zagreb_00083.png',
#  'dresden_00537.png',
#  'wuerzburg_00276.png',
#  'leipzig_00145.png',
#  'stuttgart_00316.png',
#  'marseille_00515.png',
#  'budapest_00007.png',
#  'zagreb_00643.png',
#  'toulouse_00270.png',
#  'torino_00709.png',
#  'zagreb_00026.png',
#  'potsdam_00275.png',
#  'ljubljana_00411.png',
#  'ulm_00545.png',
#  'milano_00657.png',
#  'berlin_00148.png',
#  'marseille_00255.png',
#  'budapest_00368.png',
#  'zuerich_00183.png',
#  'bratislava_00644.png',
#  'ljubljana_00872.png',
#  'marseille_01307.png',
#  'barcelona_00542.png',
#  'torino_00104.png',
#  'amsterdam_00139.png',
#  'budapest_00629.png',
#  'brno_00164.png',
#  'marseille_00041.png',
#  'lyon_00166.png',
#  'milano_00513.png',
#  'leipzig_00196.png',
#  'roma_00233.png',
#  'amsterdam_00201.png',
#  'pisa_00114.png',
#  'barcelona_00083.png',
#  'bologna_01173.png',
#  'roma_00872.png',
#  'budapest_00661.png',
#  'prague_00237.png',
#  'amsterdam_00507.png',
#  'nuernberg_00138.png',
#  'firenze_00200.png',
#  'nuernberg_00429.png',
#  'bologna_00460.png',
#  'firenze_00156.png',
#  'lyon_00197.png',
#  'pisa_00290.png',
#  'roma_00592.png',
#  'torino_00034.png',
#  'milano_00064.png',
#  'nuernberg_00622.png',
#  'hamburg_00172.png',
#  'roma_01015.png',
#  'brno_00730.png',
#  'bratislava_00476.png',
#  'stuttgart_00401.png',
#  'potsdam_00138.png',
#  'nuernberg_00349.png',
#  'marseille_00186.png',
#  'budapest_00599.png',
#  'barcelona_00976.png',
#  'amsterdam_00947.png',
#  'barcelona_01226.png',
#  'wuerzburg_00428.png',
#  'toulouse_00594.png',
#  'torino_00759.png',
#  'bologna_00771.png',
#  'torino_00557.png',
#  'bologna_00348.png',
#  'barcelona_00361.png',
#  'firenze_00665.png',
#  'amsterdam_00124.png',
#  'potsdam_00434.png',
#  'szczecin_00296.png',
#  'dresden_00019.png',
#  'torino_00336.png',
#  'wuerzburg_00065.png',
#  'prague_00148.png',
#  'torino_00799.png',
#  'milano_00048.png',
#  'stuttgart_00456.png',
#  'szczecin_00362.png',
#  'marseille_00563.png',
#  'lyon_00176.png',
#  'torino_00403.png',
#  'dresden_00310.png',
#  'budapest_00581.png',
#  'pisa_00452.png',
#  'nuernberg_00661.png',
#  'berlin_00351.png',
#  'basel_00359.png',
#  'montpellier_00183.png',
#  'zuerich_00007.png',
#  'ljubljana_00431.png',
#  'ljubljana_00788.png',
#  'bologna_00869.png',
#  'budapest_00304.png',
#  'koeln_00084.png',
#  'zagreb_00187.png',
#  'wuerzburg_00336.png',
#  'torino_00201.png',
#  'firenze_00524.png',
#  'firenze_00358.png',
#  'zagreb_00578.png',
#  'nuernberg_00073.png',
#  'nuernberg_00294.png',
#  'brno_00801.png',
#  'bologna_00023.png',
#  'montpellier_00499.png',
#  'stuttgart_00501.png',
#  'amsterdam_00220.png',
#  'amsterdam_00976.png',
#  'barcelona_00170.png',
#  'ljubljana_00719.png',
#  'pisa_00080.png',
#  'szczecin_00119.png',
#  'prague_00780.png',
#  'marseille_00319.png',
#  'pisa_00243.png',
#  'pisa_00060.png',
#  'leipzig_00128.png',
#  'toulouse_00235.png',
#  'budapest_00534.png',
#  'zagreb_00684.png',
#  'wuerzburg_00084.png',
#  'toulouse_00200.png',
#  'montpellier_00333.png',
#  'dresden_00619.png',
#  'roma_00580.png',
#  'toulouse_00133.png',
#  'roma_00658.png',
#  'prague_01047.png',
#  'basel_00514.png',
#  'bologna_00627.png',
#  'wuerzburg_00062.png',
#  'marseille_01238.png',
#  'wuerzburg_00086.png',
#  'pisa_00605.png',
#  'prague_00117.png',
#  'szczecin_00334.png',
#  'berlin_00380.png',
#  'marseille_00590.png',
#  'lyon_00148.png',
#  'bologna_00578.png',
#  'prague_00048.png',
#  'torino_00984.png',
#  'budapest_00053.png',
#  'brno_00479.png',
#  'hamburg_00649.png',
#  'stuttgart_00405.png',
#  'brno_00294.png',
#  'roma_00064.png',
#  'toulouse_00043.png',
#  'montpellier_00379.png',
#  'berlin_00014.png',
#  'dresden_00229.png',
#  'szczecin_00002.png',
#  'lyon_00131.png',
#  'potsdam_00186.png',
#  'hamburg_00558.png',
#  'bologna_00225.png',
#  'firenze_00220.png',
#  'ljubljana_00026.png',
#  'montpellier_00472.png',
#  'ljubljana_00738.png',
#  'szczecin_00016.png',
#  'prague_00612.png',
#  'prague_00951.png',
#  'ulm_00191.png',
#  'bologna_00386.png',
#  'barcelona_01161.png',
#  'firenze_00454.png',
#  'amsterdam_00722.png',
#  'bratislava_00457.png',
#  'wuerzburg_00216.png',
#  'firenze_00023.png',
#  'wuerzburg_00660.png',
#  'barcelona_00363.png',
#  'koeln_00118.png',
#  'budapest_00688.png',
#  'milano_00166.png',
#  'szczecin_00267.png',
#  'leipzig_00163.png',
#  'marseille_01001.png',
#  'milano_00619.png',
#  'milano_00526.png',
#  'torino_00401.png',
#  'marseille_00787.png',
#  'firenze_00606.png',
#  'bratislava_00765.png',
#  'milano_00796.png',
#  'bologna_01118.png',
#  'marseille_00798.png',
#  'brno_00065.png',
#  'milano_00134.png',
#  'ljubljana_00713.png',
#  'hamburg_00315.png',
#  'hamburg_00233.png',
#  'torino_00357.png',
#  'zagreb_00180.png',
#  'marseille_00309.png',
#  'ljubljana_00677.png',
#  'milano_00302.png',
#  'ljubljana_00229.png',
#  'torino_00105.png',
#  'amsterdam_00654.png',
#  'barcelona_01229.png',
#  'marseille_00047.png',
#  'pisa_00208.png',
#  'potsdam_00070.png',
#  'leipzig_00188.png',
#  'potsdam_00380.png',
#  'amsterdam_00303.png',
#  'bratislava_00379.png',
#  'amsterdam_01009.png',
#  'ulm_00209.png',
#  'prague_00206.png',
#  'prague_00632.png',
#  'bologna_01091.png',
#  'barcelona_00198.png',
#  'milano_00183.png',
#  'roma_01116.png',
#  'milano_00256.png',
#  'marseille_00276.png',
#  'ljubljana_00357.png',
#  'roma_00892.png',
#  'hamburg_00462.png',
#  'pisa_00437.png',
#  'pisa_00446.png',
#  'hamburg_00057.png',
#  'ulm_00072.png',
#  'bologna_00361.png',
#  'milano_00888.png',
#  'firenze_00411.png',
#  'ulm_00055.png',
#  'prague_00355.png',
#  'roma_00719.png',
#  'prague_00961.png',
#  'brno_00304.png',
#  'bologna_00459.png',
#  'zuerich_00022.png',
#  'szczecin_00050.png',
#  'firenze_00844.png',
#  'bologna_00043.png',
#  'roma_01028.png',
#  'barcelona_00098.png',
#  'zagreb_00126.png',
#  'roma_00484.png',
#  'stuttgart_00249.png',
#  'prague_00656.png',
#  'torino_00711.png',
#  'pisa_00393.png',
#  'milano_00020.png',
#  'zuerich_00131.png',
#  'bologna_01143.png',
#  'marseille_00595.png',
#  'montpellier_00205.png',
#  'prague_01122.png',
#  'zuerich_00145.png',
#  'roma_01065.png',
#  'nuernberg_00727.png',
#  'roma_00729.png',
#  'wuerzburg_00562.png',
#  'hamburg_00652.png',
#  'lyon_00052.png',
#  'pisa_00110.png',
#  'marseille_00203.png',
#  'zagreb_00622.png',
#  'hamburg_00219.png',
#  'szczecin_00381.png',
#  'ulm_00343.png',
#  'bologna_00661.png',
#  'ljubljana_00282.png',
#  'prague_00024.png',
#  'amsterdam_01026.png',
#  'szczecin_00333.png',
#  'stuttgart_00380.png',
#  'zagreb_00494.png',
#  'potsdam_00417.png',
#  'pisa_00133.png',
#  'firenze_00393.png',
#  'montpellier_00358.png',
#  'amsterdam_00578.png',
#  'zuerich_00126.png',
#  'barcelona_00635.png',
#  'amsterdam_01072.png',
#  'roma_00826.png',
#  'bratislava_00756.png',
#  'basel_00010.png',
#  'milano_00382.png',
#  'berlin_00216.png',
#  'barcelona_00221.png',
#  'dresden_00441.png',
#  'bologna_00802.png',
#  'ljubljana_00432.png',
#  'barcelona_01149.png',
#  'zagreb_00650.png',
#  'marseille_00920.png',
#  'roma_00342.png',
#  'stuttgart_00485.png',
#  'marseille_01242.png',
#  'wuerzburg_00123.png',
#  'potsdam_00181.png',
#  'roma_00467.png',
#  'milano_00744.png',
#  'pisa_00434.png',
#  'wuerzburg_00598.png',
#  'brno_00782.png',
#  'basel_00410.png',
#  'marseille_00613.png',
#  'marseille_00446.png',
#  'marseille_00083.png',
#  'amsterdam_00856.png',
#  'toulouse_00494.png',
#  'basel_00485.png',
#  'potsdam_00197.png',
#  'roma_00150.png',
#  'dresden_00177.png',
#  'pisa_00106.png',
#  'montpellier_00476.png',
#  'bologna_00980.png',
#  'ulm_00355.png',
#  'prague_00358.png',
#  'milano_00520.png',
#  'milano_00285.png',
#  'torino_00040.png',
#  'torino_00660.png',
#  'bratislava_00654.png',
#  'milano_00104.png',
#  'milano_00417.png',
#  'firenze_00272.png',
#  'wuerzburg_00659.png',
#  'barcelona_01231.png',
#  'amsterdam_00989.png',
#  'basel_00230.png',
#  'bratislava_00198.png',
#  'nuernberg_00495.png',
#  'wuerzburg_00102.png',
#  'basel_00431.png',
#  'brno_00265.png',
#  'marseille_01277.png',
#  'nuernberg_00049.png',
#  'budapest_00472.png',
#  'toulouse_00422.png',
#  'berlin_00343.png',
#  'budapest_00184.png',
#  'firenze_01090.png',
#  'berlin_00378.png',
#  'milano_00084.png',
#  'prague_01077.png',
#  'nuernberg_00553.png',
#  'montpellier_00575.png',
#  'roma_00845.png',
#  'ulm_00033.png',
#  'budapest_00139.png',
#  'barcelona_01038.png',
#  'ljubljana_00764.png',
#  'bologna_01067.png',
#  'milano_00585.png',
#  'firenze_01083.png',
#  'stuttgart_00520.png',
#  'nuernberg_00795.png',
#  'barcelona_00026.png',
#  'torino_00546.png',
#  'pisa_00490.png',
#  'koeln_00061.png',
#  'marseille_01097.png',
#  'lyon_00183.png',
#  'milano_00317.png']

# %%
pd.set_option('display.max_colwidth', None)
selected_ecp_img_df.file_name
# Out:
# 1169               EuroCity/ECP/day/img/train/torino/torino_00423.png
# 6449               EuroCity/ECP/day/img/train/zagreb/zagreb_00056.png
# 5032     EuroCity/ECP/day/img/train/montpellier/montpellier_00471.png
# 14142            EuroCity/ECP/day/img/train/hamburg/hamburg_00256.png
# 1897             EuroCity/ECP/day/img/train/dresden/dresden_00206.png
#                                      ...
# 9756                   EuroCity/ECP/day/img/train/pisa/pisa_00490.png
# 8362                 EuroCity/ECP/day/img/train/koeln/koeln_00061.png
# 12891        EuroCity/ECP/day/img/train/marseille/marseille_01097.png
# 8267                   EuroCity/ECP/day/img/train/lyon/lyon_00183.png
# 10977              EuroCity/ECP/day/img/train/milano/milano_00317.png
# Name: file_name, Length: 871, dtype: object

# %%
print(aug_img_df.shape[0])
aug_img_df, selected_ecp_ann_df = uodate_id_in_image_ann(selected_ecp_img_df, aug_img_df, selected_ecp_ann_df)
print(aug_img_df.shape[0])
# Out:
# 2529
# 3400

# %%
selected_ecp_ann_df = add_area(selected_ecp_ann_df)
print(selected_ecp_ann_df.shape[0])
ann_df_c = concat_ann_df(cp_ann_df, selected_ecp_ann_df)
for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']
ann_df_c
# Out:
# 7528
#           id  image_id  category_id  iscrowd                           bbox  \
# 0          1         1            1     True      [1137.0, 307.0, 8.0, 9.0]
# 1          2         1            1     True    [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1     True    [1034.0, 366.0, 31.0, 75.0]
# 3          4         2            1    False    [281.0, 381.0, 89.0, 216.0]
# 4          5         2            1    False    [602.0, 413.0, 60.0, 146.0]
# ...      ...       ...          ...      ...                            ...
# 31179  31180      3014            1     True     [972.0, 430.0, 12.0, 26.0]
# 31180  31181      2833            1     True   [190.0, 165.0, 120.0, 329.0]
# 31181  31182      2833            1     True    [639.0, 218.0, 71.0, 169.0]
# 31182  31183      2947            1     True  [1304.0, 557.0, 158.0, 265.0]
# 31183  31184      2947            1     True  [1304.0, 477.0, 133.0, 307.0]
#
#        width  height   area
# 0       2048    1024     72
# 1       2048    1024    540
# 2       2048    1024   2325
# 3       2048    1024  19224
# 4       2048    1024   8760
# ...      ...     ...    ...
# 31179   1920    1024    312
# 31180   1920    1024  39480
# 31181   1920    1024  11999
# 31182   1920    1024  41870
# 31183   1920    1024  40831
#
# [31184 rows x 8 columns]

# %%
print(ann_df_c.shape[0])
# Out:
# 31184

# %% [markdown]
# ### crowdHuman

# %%
ch_file = 'json_files/CrowdHuman/train.json'

f = open(ch_file)
ch_data = json.load(f)
# ch_licenses = ch_data['licenses']
ch_categories = ch_data['categories']
ch_images = ch_data['images']
ch_annotations = ch_data['annotations']
ch_img_df = pd.DataFrame(ch_images)
ch_ann_df = pd.DataFrame(ch_annotations)

# %%
print(ch_data['categories'])
# Out:
# [{'supercategory': 'none', 'id': 1, 'name': 'person'}, {'supercategory': 'none', 'id': 2, 'name': 'mask'}]

# %%
bb_df = copy.deepcopy(ch_ann_df[ch_ann_df.category_id == 1])
ch_ann_df = bb_df.copy()
ch_ann_df
# Out:
#           area  iscrowd  image_id                   bbox  \
# 0        86523        0         1    [61, 123, 191, 453]
# 1        92378        0         1    [165, 95, 187, 494]
# 2        96135        0         1   [236, 104, 195, 493]
# 3        85852        0         1   [452, 110, 169, 508]
# 4        62103        0         1    [520, 95, 163, 381]
# ...        ...      ...       ...                    ...
# 438781  286612        0     15000  [3393, 590, 316, 907]
# 438782   81890        0     15000  [3448, 607, 190, 431]
# 438783  240570        0     15000  [3684, 554, 297, 810]
# 438784  234855        0     15000  [3797, 536, 255, 921]
# 438785  241056        0     15000  [3863, 544, 248, 972]
#
#                          hbox                   vbox  category_id      id  \
# 0          [123, 129, 63, 64]    [62, 126, 154, 446]            1       1
# 1           [214, 97, 58, 74]    [175, 95, 140, 487]            1       2
# 2          [318, 109, 58, 68]   [260, 106, 170, 487]            1       3
# 3          [486, 119, 61, 74]   [455, 113, 141, 501]            1       4
# 4          [559, 105, 53, 57]     [553, 98, 70, 118]            1       5
# ...                       ...                    ...          ...     ...
# 438781  [3518, 595, 114, 133]  [3393, 590, 316, 907]            1  438782
# 438782   [3511, 610, 93, 104]  [3452, 608, 184, 430]            1  438783
# 438783   [3824, 559, 96, 105]  [3795, 559, 156, 794]            1  438784
# 438784   [3909, 539, 89, 113]  [3889, 535, 112, 169]            1  438785
# 438785   [3954, 561, 98, 126]  [3863, 544, 137, 972]            1  438786
#
#         ignore
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 438781       0
# 438782       0
# 438783       0
# 438784       0
# 438785       0
#
# [352983 rows x 9 columns]

# %%
for idx, row in ch_img_df.iterrows():
    ch_img_df.at[ch_img_df.index[idx], 'file_name'] = 'CrowdHuman/Images/' + ch_img_df.at[ch_img_df.index[idx], 'file_name']
ch_img_df
# Out:
#                                             file_name  height  width     id
# 0        CrowdHuman/Images/284193,faa9000f2678b5e.jpg     683   1024      1
# 1       CrowdHuman/Images/273275,cd061000af95f691.jpg     480    600      2
# 2       CrowdHuman/Images/273278,8d231000e09fc133.jpg    1017   1300      3
# 3       CrowdHuman/Images/283554,2cd4d0007833968d.jpg     954   1300      4
# 4       CrowdHuman/Images/283554,37ba1000a6ca8c4d.jpg     533    800      5
# ...                                               ...     ...    ...    ...
# 14995   CrowdHuman/Images/273275,874d9000417e16ed.jpg    1192   1800  14996
# 14996   CrowdHuman/Images/273278,d329e000260a8cc2.jpg     600   1800  14997
# 14997   CrowdHuman/Images/282555,c5fd20007faf5f84.jpg     575   1024  14998
# 14998  CrowdHuman/Images/273275,10b78d0006d7d7b9c.jpg     462   1838  14999
# 14999   CrowdHuman/Images/284193,2e02d0003abd1bb1.jpg    1912   4000  15000
#
# [15000 rows x 4 columns]

# %%
train_img_ch, val_img_ch, test_img_ch = splite_data(ch_img_df, train_size=562, val_size=121, test_size=120)

# %%
index_id_list = find_index_of_images(ch_img_df, image_name_list=train_img_ch)
selected_ch_img_df = create_img_df(ch_img_df, index_id_list)
selected_ch_ann_df = create_ann_df(ch_ann_df, index_id_list)
selected_ch_img_df
# Out:
#                                            file_name  height  width    id
# 5086   CrowdHuman/Images/273271,2a2ca0002e909b29.jpg    1952   2576  5087
# 7192   CrowdHuman/Images/284193,15d2400054b0958b.jpg     511    768  7193
# 5508   CrowdHuman/Images/273278,f175b0004e0340e0.jpg    3216   4288  5509
# 5241   CrowdHuman/Images/282555,523cf000eb66f35c.jpg     960   1450  5242
# 1930   CrowdHuman/Images/283992,105be0001e20487f.jpg     480    852  1931
# ...                                              ...     ...    ...   ...
# 722    CrowdHuman/Images/273275,d134b00079aab5f0.jpg    2136   2848   723
# 5555  CrowdHuman/Images/273275,139d6800022ebfb5d.jpg     705    998  5556
# 9569   CrowdHuman/Images/284193,1f37f000ecd86b93.jpg    2934   4102  9570
# 4100   CrowdHuman/Images/273278,89adf0008b0454dd.jpg     525    800  4101
# 3020   CrowdHuman/Images/273278,e7c36000d81b61b2.jpg    4016   5035  3021
#
# [562 rows x 4 columns]

# %%
print(selected_ch_img_df.shape[0])
selected_ch_ann_df.shape[0]
# Out:
# 562
# 13104

# %%
print(aug_img_df.shape[0])
aug_img_df, selected_ch_ann_df = uodate_id_in_image_ann(selected_ch_img_df, aug_img_df, selected_ch_ann_df, dt='ch')
aug_img_df.shape[0]
# Out:
# 3091
# 3653

# %%
selected_ch_ann_df.shape[0]
# Out:
# 13104

# %%
selected_ch_ann_df = add_area(selected_ch_ann_df)
print(ann_df_c.shape[0])
ann_df_c = concat_ann_df(ann_df_c, selected_ch_ann_df)
ann_df_c = ann_df_c.drop(['hbox', 'vbox'], axis = 1)
ann_df_c
# Out:
# 28381
#           id  image_id  category_id  iscrowd                         bbox  \
# 0          1         1            1        1    [1137.0, 307.0, 8.0, 9.0]
# 1          2         1            1        1  [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1        1  [1034.0, 366.0, 31.0, 75.0]
# 3          4         2            1        0  [281.0, 381.0, 89.0, 216.0]
# 4          5         2            1        0  [602.0, 413.0, 60.0, 146.0]
# ...      ...       ...          ...      ...                          ...
# 41480  41481      3216            1        0      [4429, 1772, 375, 1347]
# 41481  41482      3216            1        0      [4577, 1884, 388, 1341]
# 41482  41483      3216            1        0      [4868, 1902, 345, 1322]
# 41483  41484      3216            1        0      [4698, 1887, 345, 1267]
# 41484  41485      3216            1        0      [3937, 1785, 385, 1307]
#
#       width height    area  ignore
# 0      2048   1024      72     NaN
# 1      2048   1024     540     NaN
# 2      2048   1024    2325     NaN
# 3      2048   1024   19224     NaN
# 4      2048   1024    8760     NaN
# ...     ...    ...     ...     ...
# 41480  5035   4016  505125     0.0
# 41481  5035   4016  520308     0.0
# 41482  5035   4016  456090     0.0
# 41483  5035   4016  437115     0.0
# 41484  5035   4016  503195     0.0
#
# [41485 rows x 9 columns]

# %% [markdown]
# ### wheelchair

# %%
wheel_file = 'datasets/selected_oi/train.json'

f = open(wheel_file)
wheel_data = json.load(f)
wheel_categories = wheel_data['categories']
wheel_images = wheel_data['images']
wheel_annotations = wheel_data['annotations']
wheel_img_df = pd.DataFrame(wheel_images)
wheel_ann_df = pd.DataFrame(wheel_annotations)
print(wheel_img_df.shape[0])
# Out:
# 20

# %%
print(wheel_data['categories'])
# Out:
# [{'id': 1, 'name': 'pedestrain', 'supercategory': 'pedestrain'}]

# %%
wheel_ann_df = add_area(wheel_ann_df)

print(wheel_ann_df.shape[0])
# Out:
# 46

# %%
selected_img_df = copy.deepcopy(wheel_img_df)
selected_ann_df = copy.deepcopy(wheel_ann_df)

# %%
print(aug_img_df.shape[0])
aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df)
print(aug_img_df.shape[0])
# aug_img_df = copy.deepcopy(wheel_img_df)
# Out:
# 3653
# 3673

# %%
print(ann_df_c.shape[0])
print(selected_ann_df.shape[0])
ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)
# ann_df_c = copy.deepcopy(wheel_ann_df)
ann_df_c
print(ann_df_c.shape[0])
# Out:
# 41485
# 46
# 41531

# %%
for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']

# %% [markdown]
# ### WP

# %%
wp1_file = 'json_files/WiderPerson/train.json'

f = open(wp1_file)
wp_data = json.load(f)
wp_categories = wp_data['categories']
wp_images = wp_data['images']
wp_annotations = wp_data['annotations']
wp_img_df = pd.DataFrame(wp_images)
wp_ann_df = pd.DataFrame(wp_annotations)
wp_img_df.shape[0]
# Out:
# 8000

# %%
wp_ann_df
# Out:
#             id  image_id  category_id  iscrowd                         bbox  \
# 0            1         1            1    False    [45.0, 235.0, 34.0, 83.0]
# 1            2         1            1    False   [60.0, 209.0, 60.0, 147.0]
# 2            3         1            1    False  [119.0, 214.0, 49.0, 122.0]
# 3            4         1            1    False   [94.0, 220.0, 42.0, 106.0]
# 4            5         1            1    False  [213.0, 201.0, 74.0, 180.0]
# ...        ...       ...          ...      ...                          ...
# 241804  241805      8000            1    False    [233.0, 83.0, 15.0, 18.0]
# 241805  241806      8000            1    False     [34.0, 88.0, 18.0, 40.0]
# 241806  241807      8000            1    False     [66.0, 87.0, 15.0, 27.0]
# 241807  241808      8000            1    False    [161.0, 79.0, 16.0, 21.0]
# 241808  241809      8000            1    False    [141.0, 70.0, 16.0, 15.0]
#
#         width  height
# 0         550     413
# 1         550     413
# 2         550     413
# 3         550     413
# 4         550     413
# ...       ...     ...
# 241804    385     257
# 241805    385     257
# 241806    385     257
# 241807    385     257
# 241808    385     257
#
# [241809 rows x 7 columns]

# %%
print(wp_data['categories'])
# Out:
# [{'id': 1, 'name': 'pedestrain', 'supercategory': 'pedestrain'}]

# %%
train_img_wp, val_img_wp, test_img_wp = splite_data(wp_img_df, train_size=358, val_size=77,test_size=77)
index_id_list = find_index_of_images(wp_img_df, image_name_list=train_img_wp)

# %%
selected_wp_img_df = create_img_df(wp_img_df, index_id_list)
selected_wp_img_df.shape[0]
# Out:
# 358

# %%
selected_wp_ann_df = create_ann_df(wp_ann_df, index_id_list)
selected_wp_ann_df = add_area(selected_wp_ann_df)
selected_wp_ann_df.shape[0]
# Out:
# 10730

# %%
print(aug_img_df.shape[0])
aug_img_df, selected_wp_ann_df = uodate_id_in_image_ann(selected_wp_img_df, aug_img_df, selected_wp_ann_df)

print(aug_img_df.shape[0])
# Out:
# 3673
# 4031

# %%
selected_wp_ann_df.shape[0]
# Out:
# 10730

# %%
ann_df_c = concat_ann_df(ann_df_c, selected_wp_ann_df)
# ann_df_c

for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']

# %%
ann_df_c.shape[0]
# Out:
# 52261

# %%
ann_df_c
# Out:
#           id  image_id  category_id  iscrowd                         bbox  \
# 0          1         1            1        1    [1137.0, 307.0, 8.0, 9.0]
# 1          2         1            1        1  [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1        1  [1034.0, 366.0, 31.0, 75.0]
# 3          4         2            1        0  [281.0, 381.0, 89.0, 216.0]
# 4          5         2            1        0  [602.0, 413.0, 60.0, 146.0]
# ...      ...       ...          ...      ...                          ...
# 52256  52257      3977            1        0   [141.0, 104.0, 19.0, 34.0]
# 52257  52258      3977            1        0   [165.0, 113.0, 21.0, 26.0]
# 52258  52259      3977            1        0   [159.0, 103.0, 23.0, 20.0]
# 52259  52260      3977            1        0   [230.0, 122.0, 68.0, 74.0]
# 52260  52261      3977            1        1     [1.0, 67.0, 264.0, 42.0]
#
#       width height   area  ignore
# 0      2048   1024     72     NaN
# 1      2048   1024    540     NaN
# 2      2048   1024   2325     NaN
# 3      2048   1024  19224     NaN
# 4      2048   1024   8760     NaN
# ...     ...    ...    ...     ...
# 52256   300    200    646     NaN
# 52257   300    200    546     NaN
# 52258   300    200    460     NaN
# 52259   300    200   5032     NaN
# 52260   300    200  11088     NaN
#
# [52261 rows x 9 columns]

# %% [markdown]
# #### selected caltech

# %%
ca_file = 'datasets/rand_cal/train.json'

f = open(ca_file)
cl_data = json.load(f)
cl_categories = cl_data['categories']
cl_images = cl_data['images']
cl_annotations = cl_data['annotations']
cl_img_df = pd.DataFrame(cl_images)
cl_ann_df = pd.DataFrame(cl_annotations)
cl_img_df
# Out:
#       id                                  file_name  width  height  \
# 0      1  rand_cal/images/train/set02_V001_1309.png    640     480
# 1      2  rand_cal/images/train/set00_V004_1946.png    640     480
# 2      3   rand_cal/images/train/set04_V010_995.png    640     480
# 3      4  rand_cal/images/train/set00_V006_1897.png    640     480
# 4      5  rand_cal/images/train/set05_V008_1082.png    640     480
# ..   ...                                        ...    ...     ...
# 196  197   rand_cal/images/train/set06_V000_936.png    640     480
# 197  198  rand_cal/images/train/set04_V006_1005.png    640     480
# 198  199  rand_cal/images/train/set00_V002_1266.png    640     480
# 199  200   rand_cal/images/train/set03_V004_643.png    640     480
# 200  201   rand_cal/images/train/set02_V009_153.png    640     480
#
#                   date_captured  license coco_url flickr_url
# 0    2021-04-18 13:30:31.472309        1
# 1    2021-04-18 13:30:31.472309        1
# 2    2021-04-18 13:30:31.472309        1
# 3    2021-04-18 13:30:31.472309        1
# 4    2021-04-18 13:30:31.472309        1
# ..                          ...      ...      ...        ...
# 196  2021-04-18 13:30:31.472309        1
# 197  2021-04-18 13:30:31.472309        1
# 198  2021-04-18 13:30:31.472309        1
# 199  2021-04-18 13:30:31.472309        1
# 200  2021-04-18 13:30:31.472309        1
#
# [201 rows x 8 columns]

# %%
cl_ann_df = add_area(cl_ann_df)

# %%
selected_img_df = copy.deepcopy(cl_img_df)
selected_ann_df = copy.deepcopy(cl_ann_df)
aug_img_df.shape[0] + selected_img_df.shape[0]
# Out:
# 4232

# %%
aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df)

aug_img_df
# Out:
#         id                                          file_name  width  height  \
# 0        1  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 1        2  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 2        3  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 3        4  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 4        5  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# ...    ...                                                ...    ...     ...
# 4227  4228           rand_cal/images/train/set06_V000_936.png    640     480
# 4228  4229          rand_cal/images/train/set04_V006_1005.png    640     480
# 4229  4230          rand_cal/images/train/set00_V002_1266.png    640     480
# 4230  4231           rand_cal/images/train/set03_V004_643.png    640     480
# 4231  4232           rand_cal/images/train/set02_V009_153.png    640     480
#
#                    date_captured  license coco_url flickr_url
# 0     2019-07-25 11:20:43.195846      1.0
# 1     2019-07-25 11:20:43.195846      1.0
# 2     2019-07-25 11:20:43.195846      1.0
# 3     2019-07-25 11:20:43.195846      1.0
# 4     2019-07-25 11:20:43.195846      1.0
# ...                          ...      ...      ...        ...
# 4227  2021-04-18 13:30:31.472309      1.0
# 4228  2021-04-18 13:30:31.472309      1.0
# 4229  2021-04-18 13:30:31.472309      1.0
# 4230  2021-04-18 13:30:31.472309      1.0
# 4231  2021-04-18 13:30:31.472309      1.0
#
# [4232 rows x 8 columns]

# %%
aug_img_df.shape[0]
# Out:
# 4232

# %%
selected_ann_df.shape[0] + ann_df_c.shape[0]
# Out:
# 52470

# %%
ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)

for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']

ann_df_c
# Out:
#           id  image_id  category_id  iscrowd                         bbox  \
# 0          1         1            1        1    [1137.0, 307.0, 8.0, 9.0]
# 1          2         1            1        1  [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1        1  [1034.0, 366.0, 31.0, 75.0]
# 3          4         2            1        0  [281.0, 381.0, 89.0, 216.0]
# 4          5         2            1        0  [602.0, 413.0, 60.0, 146.0]
# ...      ...       ...          ...      ...                          ...
# 52465  52466      4226            1        0           [544, 190, 22, 53]
# 52466  52467      4226            1        0           [493, 195, 22, 42]
# 52467  52468      4227            1        0           [512, 171, 28, 72]
# 52468  52469      4227            1        0           [542, 170, 95, 72]
# 52469  52470      4230            1        0           [523, 164, 13, 35]
#
#       width height   area  ignore
# 0      2048   1024     72     NaN
# 1      2048   1024    540     NaN
# 2      2048   1024   2325     NaN
# 3      2048   1024  19224     NaN
# 4      2048   1024   8760     NaN
# ...     ...    ...    ...     ...
# 52465   640    480   1166     NaN
# 52466   640    480    924     NaN
# 52467   640    480   2016     NaN
# 52468   640    480   6840     NaN
# 52469   640    480    455     NaN
#
# [52470 rows x 9 columns]

# %%
ann_df_c["iscrowd"].replace({1: True, 0:False}, inplace=True)
ann_df_c['ignore'] = ann_df_c['ignore'].fillna(0)
# ann_df_c = ann_df_c.drop(['hbox', 'vbox'], axis = 1)
ann_df_c
# Out:
#           id  image_id  category_id  iscrowd                         bbox  \
# 0          1         1            1     True    [1137.0, 307.0, 8.0, 9.0]
# 1          2         1            1     True  [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1     True  [1034.0, 366.0, 31.0, 75.0]
# 3          4         2            1    False  [281.0, 381.0, 89.0, 216.0]
# 4          5         2            1    False  [602.0, 413.0, 60.0, 146.0]
# ...      ...       ...          ...      ...                          ...
# 52465  52466      4226            1    False           [544, 190, 22, 53]
# 52466  52467      4226            1    False           [493, 195, 22, 42]
# 52467  52468      4227            1    False           [512, 171, 28, 72]
# 52468  52469      4227            1    False           [542, 170, 95, 72]
# 52469  52470      4230            1    False           [523, 164, 13, 35]
#
#       width height   area  ignore
# 0      2048   1024     72     0.0
# 1      2048   1024    540     0.0
# 2      2048   1024   2325     0.0
# 3      2048   1024  19224     0.0
# 4      2048   1024   8760     0.0
# ...     ...    ...    ...     ...
# 52465   640    480   1166     0.0
# 52466   640    480    924     0.0
# 52467   640    480   2016     0.0
# 52468   640    480   6840     0.0
# 52469   640    480    455     0.0
#
# [52470 rows x 9 columns]

# %%
ann_df_c[ann_df_c.category_id != 1]
# Out:
# Empty DataFrame
# Columns: [id, image_id, category_id, iscrowd, bbox, width, height, area]
# Index: []

# %%
ann_df_c
# Out:
#           id  image_id  category_id  iscrowd                           bbox  \
# 0          1         1            1     True      [1137.0, 307.0, 8.0, 9.0]
# 1          2         1            1     True    [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1     True    [1034.0, 366.0, 31.0, 75.0]
# 3          4         2            1    False    [281.0, 381.0, 89.0, 216.0]
# 4          5         2            1    False    [602.0, 413.0, 60.0, 146.0]
# ...      ...       ...          ...      ...                            ...
# 31179  31180      3014            1     True     [972.0, 430.0, 12.0, 26.0]
# 31180  31181      2833            1     True   [190.0, 165.0, 120.0, 329.0]
# 31181  31182      2833            1     True    [639.0, 218.0, 71.0, 169.0]
# 31182  31183      2947            1     True  [1304.0, 557.0, 158.0, 265.0]
# 31183  31184      2947            1     True  [1304.0, 477.0, 133.0, 307.0]
#
#        width  height   area
# 0       2048    1024     72
# 1       2048    1024    540
# 2       2048    1024   2325
# 3       2048    1024  19224
# 4       2048    1024   8760
# ...      ...     ...    ...
# 31179   1920    1024    312
# 31180   1920    1024  39480
# 31181   1920    1024  11999
# 31182   1920    1024  41870
# 31183   1920    1024  40831
#
# [31184 rows x 8 columns]

# %%
ann_df_c["iscrowd"].replace({1: True, 0:False}, inplace=True)
# ann_df_c['ignore'] = ann_df_c['ignore'].fillna(0)
ann_df_c
# Out:
#           id  image_id  category_id  iscrowd                           bbox  \
# 0          1         1            1     True      [1137.0, 307.0, 8.0, 9.0]
# 1          2         1            1     True    [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1     True    [1034.0, 366.0, 31.0, 75.0]
# 3          4         2            1    False    [281.0, 381.0, 89.0, 216.0]
# 4          5         2            1    False    [602.0, 413.0, 60.0, 146.0]
# ...      ...       ...          ...      ...                            ...
# 31179  31180      3014            1     True     [972.0, 430.0, 12.0, 26.0]
# 31180  31181      2833            1     True   [190.0, 165.0, 120.0, 329.0]
# 31181  31182      2833            1     True    [639.0, 218.0, 71.0, 169.0]
# 31182  31183      2947            1     True  [1304.0, 557.0, 158.0, 265.0]
# 31183  31184      2947            1     True  [1304.0, 477.0, 133.0, 307.0]
#
#        width  height   area
# 0       2048    1024     72
# 1       2048    1024    540
# 2       2048    1024   2325
# 3       2048    1024  19224
# 4       2048    1024   8760
# ...      ...     ...    ...
# 31179   1920    1024    312
# 31180   1920    1024  39480
# 31181   1920    1024  11999
# 31182   1920    1024  41870
# 31183   1920    1024  40831
#
# [31184 rows x 8 columns]

# %%
aug_img_df
# Out:
#         id  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 3395  3396
# 3396  3397
# 3397  3398
# 3398  3399
# 3399  3400
#
#                                                                                                 file_name  \
# 0     CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000117_000019_leftImg8bit.png
# 1     CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000080_000019_leftImg8bit.png
# 2     CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000113_000019_leftImg8bit.png
# 3     CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000103_000019_leftImg8bit.png
# 4     CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000063_000019_leftImg8bit.png
# ...                                                                                                   ...
# 3395                                                 EuroCity/ECP/day/img/train/potsdam/potsdam_00131.png
# 3396                                                 EuroCity/ECP/day/img/train/potsdam/potsdam_00408.png
# 3397                                                 EuroCity/ECP/day/img/train/potsdam/potsdam_00152.png
# 3398                                                 EuroCity/ECP/day/img/train/potsdam/potsdam_00070.png
# 3399                                                 EuroCity/ECP/day/img/train/potsdam/potsdam_00360.png
#
#       width  height               date_captured  license coco_url flickr_url
# 0      2048    1024  2019-07-25 11:20:43.195846        1
# 1      2048    1024  2019-07-25 11:20:43.195846        1
# 2      2048    1024  2019-07-25 11:20:43.195846        1
# 3      2048    1024  2019-07-25 11:20:43.195846        1
# 4      2048    1024  2019-07-25 11:20:43.195846        1
# ...     ...     ...                         ...      ...      ...        ...
# 3395   1920    1024  2019-11-03 07:44:18.143034        1
# 3396   1920    1024  2019-11-03 07:44:18.143034        1
# 3397   1920    1024  2019-11-03 07:44:18.143034        1
# 3398   1920    1024  2019-11-03 07:44:18.143034        1
# 3399   1920    1024  2019-11-03 07:44:18.143034        1
#
# [3400 rows x 8 columns]

# %% [markdown]
# ### Save to Json

# %%
aug_data_train = dict()
aug_data_train['info'] = cp_data['info']
aug_data_train['categories'] = cp_data['categories']

aug_data_train['images'] = aug_img_df.to_dict('records')
aug_data_train['annotations'] = ann_df_c.to_dict('records')

# %%
with open('datasets/random_train.json', 'w') as fp:
    json.dump(aug_data_train, fp)

# %% [markdown]
# ## Validation

# %%
cp_file = 'datasets/cityperson_val.json'
f = open(cp_file)
cp_data = json.load(f)
# cp_licenses = cp_data['licenses']
cp_categories = cp_data['categories']
cp_images = cp_data['images']
cp_annotations = cp_data['annotations']
cp_img_df = pd.DataFrame(cp_images)
cp_ann_df = pd.DataFrame(cp_annotations)

# %%
# for idx, row in cp_img_df.iterrows():
#     cp_img_df.at[cp_img_df.index[idx], 'file_name'] = 'CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/' + cp_img_df.at[cp_img_df.index[idx], 'file_name']
cp_img_df
# Out:
#       id  \
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 420  421
# 421  422
# 422  423
# 423  424
# 424  425
#
#                                                                                                       file_name  \
# 0    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_000294_leftImg8bit.png
# 1    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_000576_leftImg8bit.png
# 2    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_001751_leftImg8bit.png
# 3    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_002196_leftImg8bit.png
# 4    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_002963_leftImg8bit.png
# ..                                                                                                          ...
# 420    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/munster_000167_000019_leftImg8bit.png
# 421    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/munster_000168_000019_leftImg8bit.png
# 422    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/munster_000169_000019_leftImg8bit.png
# 423    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/munster_000170_000019_leftImg8bit.png
# 424    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/munster_000171_000019_leftImg8bit.png
#
#      height  width
# 0      1024   2048
# 1      1024   2048
# 2      1024   2048
# 3      1024   2048
# 4      1024   2048
# ..      ...    ...
# 420    1024   2048
# 421    1024   2048
# 422    1024   2048
# 423    1024   2048
# 424    1024   2048
#
# [425 rows x 4 columns]

# %%
# cp_ann_df['height'] = ""
# cp_ann_df['width'] = ""
# for idx, row in cp_img_df.iterrows():            
#     cp_ann_df.loc[cp_ann_df['image_id'] == idx + 1, 'height'] = cp_img_df.at[idx, 'height']
#     cp_ann_df.loc[cp_ann_df['image_id'] == idx + 1, 'width'] = cp_img_df.at[idx, 'width']

# %%
# cp_ann_df = cp_ann_df.drop(['vis_bbox', 'vis_ratio'], axis = 1)
# cp_ann_df = add_area(cp_ann_df)
cp_ann_df
# Out:
#         id  image_id  category_id  iscrowd  ignore                 bbox  \
# 0        1         1            1        0       1     [963, 378, 6, 8]
# 1        2         1            1        0       1  [1617, 354, 24, 31]
# 2        3         1            1        0       1  [1940, 455, 30, 54]
# 3        4         1            1        0       1  [1150, 347, 11, 14]
# 4        5         1            1        0       1  [1834, 101, 65, 58]
# ...    ...       ...          ...      ...     ...                  ...
# 4968  4969       424            1        0       0   [818, 410, 13, 32]
# 4969  4970       425            1        0       0  [1029, 423, 16, 41]
# 4970  4971       425            1        0       0  [1386, 418, 22, 53]
# 4971  4972       425            1        0       1  [1000, 424, 14, 34]
# 4972  4973       425            1        0       1  [1351, 402, 28, 68]
#
#       height  width  area
# 0       1024   2048    48
# 1       1024   2048   744
# 2       1024   2048  1620
# 3       1024   2048   154
# 4       1024   2048  3770
# ...      ...    ...   ...
# 4968    1024   2048   416
# 4969    1024   2048   656
# 4970    1024   2048  1166
# 4971    1024   2048   476
# 4972    1024   2048  1904
#
# [4973 rows x 9 columns]

# %%
aug_img_df = copy.deepcopy(cp_img_df)
ann_df_c = copy.deepcopy(cp_ann_df)

# %% [markdown]
# ### ECP

# %%
index_id_list = find_index_of_images(ecp_img_df, image_name_list=val_img_ecp)

selected_img_df = create_img_df(ecp_img_df, index_id_list)

selected_ann_df = create_ann_df(ecp_ann_df, index_id_list)
selected_ann_df = add_area(selected_ann_df)
selected_ann_df
# Out:
#             id  image_id  category_id  iscrowd                         bbox  \
# 191392  191393     22760            1    False   [153.0, 575.0, 26.0, 68.0]
# 191393  191394     22760            1    False  [613.0, 550.0, 30.0, 115.0]
# 191394  191395     22760            1    False  [618.0, 543.0, 36.0, 125.0]
# 191395  191396     22760            1    False  [1679.0, 520.0, 23.0, 78.0]
# 191396  191397     22760            1     True   [267.0, 598.0, 62.0, 46.0]
# ...        ...       ...          ...      ...                          ...
# 112582  112583     13567            1    False  [1618.0, 545.0, 21.0, 73.0]
# 112583  112584     13567            1    False  [1134.0, 550.0, 18.0, 47.0]
# 112584  112585     13567            1    False  [1233.0, 547.0, 16.0, 49.0]
# 112585  112586     13567            1     True  [1052.0, 560.0, 41.0, 44.0]
# 112586  112587     13567            1     True  [1122.0, 566.0, 46.0, 36.0]
#
#         width  height  area
# 191392   1920    1024  1768
# 191393   1920    1024  3450
# 191394   1920    1024  4500
# 191395   1920    1024  1794
# 191396   1920    1024  2852
# ...       ...     ...   ...
# 112582   1920    1024  1533
# 112583   1920    1024   846
# 112584   1920    1024   784
# 112585   1920    1024  1804
# 112586   1920    1024  1656
#
# [1335 rows x 8 columns]

# %%
selected_img_df
# Out:
#           id                                                   file_name  \
# 22759  22760    EuroCity/ECP/day/img/train/nuernberg/nuernberg_00325.png
# 22298  22299    EuroCity/ECP/day/img/train/amsterdam/amsterdam_00455.png
# 7365    7366        EuroCity/ECP/day/img/train/firenze/firenze_01134.png
# 3666    3667      EuroCity/ECP/day/img/train/budapest/budapest_00779.png
# 7591    7592        EuroCity/ECP/day/img/train/firenze/firenze_00308.png
# ...      ...                                                         ...
# 22487  22488    EuroCity/ECP/day/img/train/nuernberg/nuernberg_00270.png
# 13472  13473    EuroCity/ECP/day/img/train/ljubljana/ljubljana_00646.png
# 17544  17545          EuroCity/ECP/day/img/train/prague/prague_00297.png
# 15037  15038  EuroCity/ECP/day/img/train/bratislava/bratislava_00115.png
# 13566  13567    EuroCity/ECP/day/img/train/ljubljana/ljubljana_00236.png
#
#        width  height               date_captured  license coco_url flickr_url
# 22759   1920    1024  2019-11-03 07:44:18.143034        1
# 22298   1920    1024  2019-11-03 07:44:18.143034        1
# 7365    1920    1024  2019-11-03 07:44:18.143034        1
# 3666    1920    1024  2019-11-03 07:44:18.143034        1
# 7591    1920    1024  2019-11-03 07:44:18.143034        1
# ...      ...     ...                         ...      ...      ...        ...
# 22487   1920    1024  2019-11-03 07:44:18.143034        1
# 13472   1920    1024  2019-11-03 07:44:18.143034        1
# 17544   1920    1024  2019-11-03 07:44:18.143034        1
# 15037   1920    1024  2019-11-03 07:44:18.143034        1
# 13566   1920    1024  2019-11-03 07:44:18.143034        1
#
# [168 rows x 8 columns]

# %%
print(aug_img_df.shape[0])
aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df)
aug_img_df.shape[0]
# Out:
# 425
# 593

# %%
print(ann_df_c.shape[0])
ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)
print(ann_df_c.shape[0])
for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']

ann_df_c
# Out:
# 4973
# 6308
#         id  image_id  category_id  iscrowd  ignore  \
# 0        1         1            1        0     1.0
# 1        2         1            1        0     1.0
# 2        3         1            1        0     1.0
# 3        4         1            1        0     1.0
# 4        5         1            1        0     1.0
# ...    ...       ...          ...      ...     ...
# 6303  6304       526            1        0     NaN
# 6304  6305       526            1        0     NaN
# 6305  6306       526            1        0     NaN
# 6306  6307       526            1        1     NaN
# 6307  6308       526            1        1     NaN
#
#                              bbox  height  width  area
# 0                [963, 378, 6, 8]    1024   2048    48
# 1             [1617, 354, 24, 31]    1024   2048   744
# 2             [1940, 455, 30, 54]    1024   2048  1620
# 3             [1150, 347, 11, 14]    1024   2048   154
# 4             [1834, 101, 65, 58]    1024   2048  3770
# ...                           ...     ...    ...   ...
# 6303  [1618.0, 545.0, 21.0, 73.0]    1024   1920  1533
# 6304  [1134.0, 550.0, 18.0, 47.0]    1024   1920   846
# 6305  [1233.0, 547.0, 16.0, 49.0]    1024   1920   784
# 6306  [1052.0, 560.0, 41.0, 44.0]    1024   1920  1804
# 6307  [1122.0, 566.0, 46.0, 36.0]    1024   1920  1656
#
# [6308 rows x 9 columns]

# %% [markdown]
# ### CH

# %%
index_id_list = find_index_of_images(ch_img_df, image_name_list=val_img_ch)

selected_img_df = create_img_df(ch_img_df, index_id_list)
selected_ann_df = create_ann_df(ch_ann_df, index_id_list)
print(selected_img_df.shape[0])
print(selected_ann_df.shape[0])

selected_ann_df = add_area(selected_ann_df)

aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df, dt='ch')

print(ann_df_c.shape[0])
ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)
print(ann_df_c.shape[0])

for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']
ann_df_c
# Out:
# 121
# 2578
# 6016
# 8594
#         id  image_id  category_id  iscrowd  ignore                  bbox  \
# 0        1         1            1        0     1.0      [963, 378, 6, 8]
# 1        2         1            1        0     1.0   [1617, 354, 24, 31]
# 2        3         1            1        0     1.0   [1940, 455, 30, 54]
# 3        4         1            1        0     1.0   [1150, 347, 11, 14]
# 4        5         1            1        0     1.0   [1834, 101, 65, 58]
# ...    ...       ...          ...      ...     ...                   ...
# 8589  8590       632            1        0     0.0   [803, 515, 46, 160]
# 8590  8591       602            1        0     0.0  [-66, 426, 499, 762]
# 8591  8592       602            1        0     0.0  [148, 339, 276, 490]
# 8592  8593       602            1        0     0.0  [247, 335, 218, 352]
# 8593  8594       602            1        0     0.0  [446, 198, 286, 307]
#
#      height width    area                 hbox                  vbox
# 0      1024  2048      48                  NaN                   NaN
# 1      1024  2048     744                  NaN                   NaN
# 2      1024  2048    1620                  NaN                   NaN
# 3      1024  2048     154                  NaN                   NaN
# 4      1024  2048    3770                  NaN                   NaN
# ...     ...   ...     ...                  ...                   ...
# 8589    718  1024    7360   [815, 517, 29, 24]   [803, 515, 46, 160]
# 8590    639   959  380238  [38, 445, 197, 188]  [144, 426, 278, 215]
# 8591    639   959  135240  [218, 361, 98, 133]  [211, 342, 211, 298]
# 8592    639   959   76736   [383, 341, 65, 88]  [312, 336, 152, 303]
# 8593    639   959   87802   [547, 201, 38, 45]  [446, 198, 286, 307]
#
# [8594 rows x 11 columns]

# %%
ann_df_c = ann_df_c.drop(['hbox', 'vbox'], axis = 1)
ann_df_c
# Out:
#         id  image_id  category_id  iscrowd  ignore                  bbox  \
# 0        1         1            1        0     1.0      [963, 378, 6, 8]
# 1        2         1            1        0     1.0   [1617, 354, 24, 31]
# 2        3         1            1        0     1.0   [1940, 455, 30, 54]
# 3        4         1            1        0     1.0   [1150, 347, 11, 14]
# 4        5         1            1        0     1.0   [1834, 101, 65, 58]
# ...    ...       ...          ...      ...     ...                   ...
# 8589  8590       632            1        0     0.0   [803, 515, 46, 160]
# 8590  8591       602            1        0     0.0  [-66, 426, 499, 762]
# 8591  8592       602            1        0     0.0  [148, 339, 276, 490]
# 8592  8593       602            1        0     0.0  [247, 335, 218, 352]
# 8593  8594       602            1        0     0.0  [446, 198, 286, 307]
#
#      height width    area
# 0      1024  2048      48
# 1      1024  2048     744
# 2      1024  2048    1620
# 3      1024  2048     154
# 4      1024  2048    3770
# ...     ...   ...     ...
# 8589    718  1024    7360
# 8590    639   959  380238
# 8591    639   959  135240
# 8592    639   959   76736
# 8593    639   959   87802
#
# [8594 rows x 9 columns]

# %%
aug_img_df.shape[0]
# Out:
# 667

# %% [markdown]
# ### wheelchair

# %%
wheel_file = 'datasets/selected_oi/val.json'

f = open(wheel_file)
wheel_data = json.load(f)
wheel_categories = wheel_data['categories']
wheel_images = wheel_data['images']
wheel_annotations = wheel_data['annotations']
wheel_img_df = pd.DataFrame(wheel_images)
wheel_ann_df = pd.DataFrame(wheel_annotations)
wheel_img_df.shape[0]
# Out:
# 11

# %%
wheel_ann_df = add_area(wheel_ann_df)
selected_img_df = copy.deepcopy(wheel_img_df)
selected_ann_df = copy.deepcopy(wheel_ann_df)
print(aug_img_df.shape[0])
aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df)

aug_img_df.shape[0]
# Out:
# 667
# 678

# %%
print(ann_df_c.shape[0])

ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)

for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']

ann_df_c.shape[0]
# Out:
# 8594
# 8630

# %% [markdown]
# ## WP

# %%
index_id_list = find_index_of_images(wp_img_df, image_name_list=val_img_wp)

# %%
selected_wp_img_df = create_img_df(wp_img_df, index_id_list)
selected_wp_ann_df = create_ann_df(wp_ann_df, index_id_list)
selected_wp_ann_df = add_area(selected_wp_ann_df)
print(selected_wp_img_df.shape[0])
selected_wp_ann_df.shape[0]
# Out:
# 77
# 2101

# %%
print(aug_img_df.shape[0])
aug_img_df, selected_wp_ann_df = uodate_id_in_image_ann(selected_wp_img_df, aug_img_df, selected_wp_ann_df)
print(aug_img_df.shape[0])
# Out:
# 678
# 755

# %%
print(ann_df_c.shape[0])
ann_df_c = concat_ann_df(ann_df_c, selected_wp_ann_df)

for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']
print(ann_df_c.shape[0])
ann_df_c
# Out:
# 8630
# 10731
#           id  image_id  category_id  iscrowd  ignore  \
# 0          1         1            1        0     1.0
# 1          2         1            1        0     1.0
# 2          3         1            1        0     1.0
# 3          4         1            1        0     1.0
# 4          5         1            1        0     1.0
# ...      ...       ...          ...      ...     ...
# 10726  10727       710            1        0     NaN
# 10727  10728       710            1        0     NaN
# 10728  10729       710            1        0     NaN
# 10729  10730       710            1        0     NaN
# 10730  10731       710            1        0     NaN
#
#                              bbox height width   area
# 0                [963, 378, 6, 8]   1024  2048     48
# 1             [1617, 354, 24, 31]   1024  2048    744
# 2             [1940, 455, 30, 54]   1024  2048   1620
# 3             [1150, 347, 11, 14]   1024  2048    154
# 4             [1834, 101, 65, 58]   1024  2048   3770
# ...                           ...    ...   ...    ...
# 10726  [252.0, 62.0, 97.0, 237.0]    358   500  22989
# 10727  [305.0, 71.0, 80.0, 196.0]    358   500  15680
# 10728  [348.0, 51.0, 86.0, 212.0]    358   500  18232
# 10729  [387.0, 59.0, 79.0, 192.0]    358   500  15168
# 10730    [3.0, 94.0, 40.0, 107.0]    358   500   4280
#
# [10731 rows x 9 columns]

# %% [markdown]
# ### selected_caltech

# %%
ca_file = 'datasets/rand_cal/val.json'

f = open(ca_file)
cl_data = json.load(f)
cl_categories = cl_data['categories']
cl_images = cl_data['images']
cl_annotations = cl_data['annotations']
cl_img_df = pd.DataFrame(cl_images)
cl_ann_df = pd.DataFrame(cl_annotations)
print(cl_img_df.shape[0])
cl_ann_df = add_area(cl_ann_df)

print(cl_ann_df.shape[0])
# Out:
# 45
# 29

# %%
print(aug_img_df.shape[0])
selected_img_df = copy.deepcopy(cl_img_df)
selected_ann_df = copy.deepcopy(cl_ann_df)

aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df)

aug_img_df.shape[0]
# Out:
# 755
# 800

# %%
print(selected_ann_df.shape[0])
ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)

for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']

ann_df_c["iscrowd"].replace({1: True, 0:False}, inplace=True)
ann_df_c['ignore'] = ann_df_c['ignore'].fillna(0)
ann_df_c
# Out:
# 29
#           id  image_id  category_id  iscrowd  ignore                 bbox  \
# 0          1         1            1    False     1.0     [963, 378, 6, 8]
# 1          2         1            1    False     1.0  [1617, 354, 24, 31]
# 2          3         1            1    False     1.0  [1940, 455, 30, 54]
# 3          4         1            1    False     1.0  [1150, 347, 11, 14]
# 4          5         1            1    False     1.0  [1834, 101, 65, 58]
# ...      ...       ...          ...      ...     ...                  ...
# 10755  10756       797            1    False     0.0   [489, 162, 15, 45]
# 10756  10757       797            1    False     0.0   [440, 163, 22, 47]
# 10757  10758       797            1    False     0.0   [414, 168, 11, 33]
# 10758  10759       798            1    False     0.0    [54, 151, 18, 80]
# 10759  10760       798            1    False     0.0    [26, 150, 24, 90]
#
#       height width  area
# 0       1024  2048    48
# 1       1024  2048   744
# 2       1024  2048  1620
# 3       1024  2048   154
# 4       1024  2048  3770
# ...      ...   ...   ...
# 10755    480   640   675
# 10756    480   640  1034
# 10757    480   640   363
# 10758    480   640  1440
# 10759    480   640  2160
#
# [10760 rows x 9 columns]

# %%
aug_img_df
# Out:
#       id                                          file_name  height  width  \
# 0      1  CityPersons/leftImg8bit_trainvaltest/leftImg8b...    1024   2048
# 1      2  CityPersons/leftImg8bit_trainvaltest/leftImg8b...    1024   2048
# 2      3  CityPersons/leftImg8bit_trainvaltest/leftImg8b...    1024   2048
# 3      4  CityPersons/leftImg8bit_trainvaltest/leftImg8b...    1024   2048
# 4      5  CityPersons/leftImg8bit_trainvaltest/leftImg8b...    1024   2048
# ..   ...                                                ...     ...    ...
# 795  796            rand_cal/images/val/set03_V004_1095.png     480    640
# 796  797            rand_cal/images/val/set00_V007_1255.png     480    640
# 797  798            rand_cal/images/val/set00_V006_1590.png     480    640
# 798  799            rand_cal/images/val/set02_V005_1664.png     480    640
# 799  800             rand_cal/images/val/set02_V004_758.png     480    640
#
#                   date_captured  license coco_url flickr_url
# 0                           NaN      NaN      NaN        NaN
# 1                           NaN      NaN      NaN        NaN
# 2                           NaN      NaN      NaN        NaN
# 3                           NaN      NaN      NaN        NaN
# 4                           NaN      NaN      NaN        NaN
# ..                          ...      ...      ...        ...
# 795  2021-04-18 13:30:22.721543      1.0
# 796  2021-04-18 13:30:22.721543      1.0
# 797  2021-04-18 13:30:22.721543      1.0
# 798  2021-04-18 13:30:22.721543      1.0
# 799  2021-04-18 13:30:22.721543      1.0
#
# [800 rows x 8 columns]

# %%
aug_img_df['date_captured'] = ""
aug_img_df['license'] = ""
aug_img_df['coco_url'] = ""
aug_img_df['flickr_url'] = ""
aug_img_df
# Out:
#       id  \
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 588  589
# 589  590
# 590  591
# 591  592
# 592  593
#
#                                                                                                       file_name  \
# 0    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_000294_leftImg8bit.png
# 1    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_000576_leftImg8bit.png
# 2    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_001751_leftImg8bit.png
# 3    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_002196_leftImg8bit.png
# 4    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_002963_leftImg8bit.png
# ..                                                                                                          ...
# 588                                                    EuroCity/ECP/day/img/train/nuernberg/nuernberg_00056.png
# 589                                                        EuroCity/ECP/day/img/train/potsdam/potsdam_00007.png
# 590                                                        EuroCity/ECP/day/img/train/potsdam/potsdam_00377.png
# 591                                                        EuroCity/ECP/day/img/train/potsdam/potsdam_00448.png
# 592                                                        EuroCity/ECP/day/img/train/potsdam/potsdam_00494.png
#
#      height  width date_captured license coco_url flickr_url
# 0      1024   2048
# 1      1024   2048
# 2      1024   2048
# 3      1024   2048
# 4      1024   2048
# ..      ...    ...           ...     ...      ...        ...
# 588    1024   1920
# 589    1024   1920
# 590    1024   1920
# 591    1024   1920
# 592    1024   1920
#
# [593 rows x 8 columns]

# %%
ann_df_c[ann_df_c.category_id != 1]
# Out:
# Empty DataFrame
# Columns: [id, image_id, category_id, iscrowd, ignore, bbox, height, width, area]
# Index: []

# %%
ann_df_c["iscrowd"].replace({1: True, 0:False}, inplace=True)
ann_df_c['ignore'] = ann_df_c['ignore'].fillna(0)
ann_df_c
# Out:
#         id  image_id  category_id  iscrowd  ignore  \
# 0        1         1            1    False     1.0
# 1        2         1            1    False     1.0
# 2        3         1            1    False     1.0
# 3        4         1            1    False     1.0
# 4        5         1            1    False     1.0
# ...    ...       ...          ...      ...     ...
# 6303  6304       526            1    False     0.0
# 6304  6305       526            1    False     0.0
# 6305  6306       526            1    False     0.0
# 6306  6307       526            1     True     0.0
# 6307  6308       526            1     True     0.0
#
#                              bbox  height  width  area
# 0                [963, 378, 6, 8]    1024   2048    48
# 1             [1617, 354, 24, 31]    1024   2048   744
# 2             [1940, 455, 30, 54]    1024   2048  1620
# 3             [1150, 347, 11, 14]    1024   2048   154
# 4             [1834, 101, 65, 58]    1024   2048  3770
# ...                           ...     ...    ...   ...
# 6303  [1618.0, 545.0, 21.0, 73.0]    1024   1920  1533
# 6304  [1134.0, 550.0, 18.0, 47.0]    1024   1920   846
# 6305  [1233.0, 547.0, 16.0, 49.0]    1024   1920   784
# 6306  [1052.0, 560.0, 41.0, 44.0]    1024   1920  1804
# 6307  [1122.0, 566.0, 46.0, 36.0]    1024   1920  1656
#
# [6308 rows x 9 columns]

# %% [markdown]
# ### Save json file

# %%
aug_data_train = dict()
aug_data_train['info'] = cp_info
aug_data_train['categories'] = cp_data['categories']
aug_data_train['images'] = aug_img_df.to_dict('records')
aug_data_train['annotations'] = ann_df_c.to_dict('records')
with open('datasets/random_val.json', 'w') as fp:
    json.dump(aug_data_train, fp)
